# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.preprocessing import scale
from sklearn.metrics import mean_squared_error
import re

# %%
csv_in = 'winequality-red.csv'
df = pd.read_csv(csv_in, sep=';', skiprows=0, header=0)
print(df.shape)
print(df.info())
display(df.head())
# Out:
# (1599, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# None
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
display(df.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
X = df.drop(columns='quality')
y = df['quality']
print('X:', X.shape)
display(X.head())
print('y:', y.shape)
print(y.head())
# Out:
# X: (1599, 11)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4
# y: (1599,)
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
X_scaled_ar = scale(X)
y_scaled_ar = scale(y)

# %%
X_scaled = pd.DataFrame(X_scaled_ar, columns=X.columns)
y_scaled = pd.Series(y_scaled_ar, name=y.name)
d_scaled = pd.concat([X_scaled, y_scaled], axis=1)
display(d_scaled.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# 1      -0.298547          1.967442    -1.391472        0.043416   0.223875
# 2      -0.298547          1.297065    -1.186070       -0.169427   0.096353
# 3       1.654856         -1.384443     1.484154       -0.453218  -0.264960
# 4      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.466193             -0.379133  0.558274  1.288643  -0.579207
# 1             0.872638              0.624363  0.028261 -0.719933   0.128950
# 2            -0.083669              0.229047  0.134264 -0.331177  -0.048089
# 3             0.107592              0.411500  0.664277 -0.979104  -0.461180
# 4            -0.466193             -0.379133  0.558274  1.288643  -0.579207
#
#     alcohol   quality
# 0 -0.960246 -0.787823
# 1 -0.584777 -0.787823
# 2 -0.584777 -0.787823
# 3 -0.584777  0.450848
# 4 -0.960246 -0.787823

# %%
def step_aic_forward(model, exog, endog, **kwargs):
    exog = np.r_[[exog]].flatten()
    endog = np.r_[[endog]].flatten()
    remaining = set(exog)
    selected = []

    formula_head = 'Q("' + '") + Q("'.join(endog) + '") ~ '
    formula = formula_head + '1'
    aic = model(formula=formula, **kwargs).fit().aic
    print('AIC: {:.3f}, formula: {}'.format(aic, formula))

    current_score, best_new_score = aic, aic

    while True:
        score_with_candidates = []
        for candidate in remaining:
            formula_tail = 'Q("' + '") + Q("'.join(selected + [candidate]) + '")'
            formula = formula_head + formula_tail
            aic = model(formula=formula, **kwargs).fit().aic
            print('AIC: {:.3f}, formula: {}'.format(aic, formula))

            score_with_candidates.append((aic, candidate))

        score_with_candidates.sort()
        best_score, best_candidate = score_with_candidates[0]

        improved = False
        if best_score < current_score:
            remaining.remove(best_candidate)
            selected.append(best_candidate)
            current_score = best_score
            improved = True
            
        if not remaining or not improved: break

    formula = formula_head + 'Q("' + '") + Q("'.join(selected) + '")'
    print('The best formula: {}'.format(formula))
    aic = model(formula=formula, **kwargs).fit().aic
    print('Minimum AIC: {:.3f}'.format(aic))
    
    ret = model(formula, **kwargs).fit()
    ret.model.exog_names_org = [re.sub(r'Q\(\"(.*)\"\)',r'\1',x) for x in list(ret.model.exog_names)]
    ret.model.endog_names_org = re.sub(r'Q\(\"(.*)\"\)',r'\1',ret.model.endog_names)
    return ret

# %%
header_y = y_scaled.name
header_x = X_scaled.columns
model = step_aic_forward(smf.ols, header_x, header_y, data=d_scaled)
# Out:
# AIC: 4539.765, formula: Q("quality") ~ 1
# AIC: 4514.972, formula: Q("quality") ~ Q("chlorides")
# AIC: 4457.651, formula: Q("quality") ~ Q("citric acid")
# AIC: 4536.427, formula: Q("quality") ~ Q("pH")
# AIC: 4130.610, formula: Q("quality") ~ Q("alcohol")
# AIC: 4516.967, formula: Q("quality") ~ Q("fixed acidity")
# AIC: 4537.657, formula: Q("quality") ~ Q("free sulfur dioxide")
# AIC: 4486.020, formula: Q("quality") ~ Q("total sulfur dioxide")
# AIC: 4437.373, formula: Q("quality") ~ Q("sulphates")
# AIC: 4277.121, formula: Q("quality") ~ Q("volatile acidity")
# AIC: 4492.077, formula: Q("quality") ~ Q("density")
# AIC: 4541.464, formula: Q("quality") ~ Q("residual sugar")
# AIC: 4131.398, formula: Q("quality") ~ Q("alcohol") + Q("chlorides")
# AIC: 4067.918, formula: Q("quality") ~ Q("alcohol") + Q("citric acid")
# AIC: 4079.428, formula: Q("quality") ~ Q("alcohol") + Q("pH")
# AIC: 4082.993, formula: Q("quality") ~ Q("alcohol") + Q("fixed acidity")
# AIC: 4131.966, formula: Q("quality") ~ Q("alcohol") + Q("free sulfur dioxide")
# AIC: 4116.117, formula: Q("quality") ~ Q("alcohol") + Q("total sulfur dioxide")
# AIC: 4040.781, formula: Q("quality") ~ Q("alcohol") + Q("sulphates")
# AIC: 3934.124, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity")
# AIC: 4122.254, formula: Q("quality") ~ Q("alcohol") + Q("density")
# AIC: 4132.528, formula: Q("quality") ~ Q("alcohol") + Q("residual sugar")
# AIC: 3935.279, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("chlorides")
# AIC: 3935.689, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("citric acid")
# AIC: 3922.698, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("pH")
# AIC: 3923.254, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("fixed acidity")
# AIC: 3934.636, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("free sulfur dioxide")
# AIC: 3921.743, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("total sulfur dioxide")
# AIC: 3891.265, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates")
# AIC: 3931.758, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("density")
# AIC: 3936.102, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("residual sugar")
# AIC: 3875.860, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("chlorides")
# AIC: 3892.682, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("citric acid")
# AIC: 3886.214, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("pH")
# AIC: 3885.557, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("fixed acidity")
# AIC: 3890.692, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("free sulfur dioxide")
# AIC: 3874.166, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide")
# AIC: 3892.752, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("density")
# AIC: 3893.232, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("residual sugar")
# AIC: 3857.263, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides")
# AIC: 3875.995, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("citric acid")
# AIC: 3868.410, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("pH")
# AIC: 3871.240, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("fixed acidity")
# AIC: 3872.993, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("free sulfur dioxide")
# AIC: 3875.914, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("density")
# AIC: 3875.550, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("residual sugar")
# AIC: 3858.881, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides") + Q("citric acid")
# AIC: 3845.198, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides") + Q("pH")
# AIC: 3853.560, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides") + Q("fixed acidity")
# AIC: 3856.326, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides") + Q("free sulfur dioxide")
# AIC: 3858.902, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides") + Q("density")
# AIC: 3857.954, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides") + Q("residual sugar")
# AIC: 3845.275, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides") + Q("pH") + Q("citric acid")
# AIC: 3847.173, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides") + Q("pH") + Q("fixed acidity")
# AIC: 3841.474, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides") + Q("pH") + Q("free sulfur dioxide")
# AIC: 3847.092, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides") + Q("pH") + Q("density")
# AIC: 3846.521, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides") + Q("pH") + Q("residual sugar")
# AIC: 3842.336, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides") + Q("pH") + Q("free sulfur dioxide") + Q("citric acid")
# AIC: 3843.458, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides") + Q("pH") + Q("free sulfur dioxide") + Q("fixed acidity")
# AIC: 3843.400, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides") + Q("pH") + Q("free sulfur dioxide") + Q("density")
# AIC: 3843.074, formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides") + Q("pH") + Q("free sulfur dioxide") + Q("residual sugar")
# The best formula: Q("quality") ~ Q("alcohol") + Q("volatile acidity") + Q("sulphates") + Q("total sulfur dioxide") + Q("chlorides") + Q("pH") + Q("free sulfur dioxide")
# Minimum AIC: 3841.474

# %%
print('Selected variables:', len(model.model.exog_names_org))
print('Adjusted R-squared:', model.rsquared_adj)
print(model.summary())
# Out:
# Selected variables: 8
# Adjusted R-squared: 0.3566527489402871
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Q("quality")   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.357
# Method:                 Least Squares   F-statistic:                     127.6
# Date:                Mon, 29 Sep 2025   Prob (F-statistic):          5.32e-149
# Time:                        19:19:33   Log-Likelihood:                -1912.7
# No. Observations:                1599   AIC:                             3841.
# Df Residuals:                    1591   BIC:                             3884.
# Df Model:                           7
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                  8.327e-17      0.020   4.15e-15      1.000      -0.039       0.039
# Q("alcohol")                  0.3818      0.022     17.225      0.000       0.338       0.425
# Q("volatile acidity")        -0.2246      0.022    -10.043      0.000      -0.268      -0.181
# Q("sulphates")                0.1853      0.023      8.031      0.000       0.140       0.231
# Q("total sulfur dioxide")    -0.1418      0.028     -5.070      0.000      -0.197      -0.087
# Q("chlorides")               -0.1176      0.023     -5.076      0.000      -0.163      -0.072
# Q("pH")                      -0.0923      0.022     -4.106      0.000      -0.136      -0.048
# Q("free sulfur dioxide")      0.0658      0.028      2.389      0.017       0.012       0.120
# ==============================================================================
# Omnibus:                       24.204   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.245
# Skew:                          -0.156   Prob(JB):                     2.22e-08
# Kurtosis:                       3.657   Cond. No.                         2.44
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
