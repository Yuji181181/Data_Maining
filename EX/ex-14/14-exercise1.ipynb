# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('df_ex_fp.csv')

# %%
display(df.head())
# Out:
#   Invoice  Item
# 1  EX1200   106
# 2  EX1129   101
# 3  EX1144   115
# 4  EX1120   118
# 5  EX1040   120

# %%
top_sc = df['Item'].value_counts()

# %%
top_sc[:5]
# Out:
# Item
# 120    100
# 114     97
# 102     88
# 113     84
# 108     83
# Name: count, dtype: int64

# %%
top_sc1 = top_sc.index[0]
top_sc2 = top_sc.index[1]
print(top_sc1, top_sc2)
# Out:
# 120 114

# %%
df_sc1 = df[ df['Item']==top_sc1 ]
df_sc2 = df[ df['Item']==top_sc2 ]

# %%
iv_all = set(df['Invoice'])
iv_sc1 = set(df_sc1['Invoice'])
iv_sc2 = set(df_sc2['Invoice'])
iv_both = iv_sc1 & iv_sc2
iv_either = iv_sc1 | iv_sc2

# %%
n_all = len(iv_all)
n_sc1 = len(iv_sc1)
n_sc2 = len(iv_sc2)
n_both = len(iv_both)
n_either = len(iv_either)
print(n_all, n_sc1, n_sc2, n_both, n_either)
# Out:
# 199 77 76 31 122

# %%
print('Conf(sc1 => sc2):', n_both / n_sc1) 
print('Conf(sc2 => sc1):', n_both / n_sc2)
# Out:
# Conf(sc1 => sc2): 0.4025974025974026
# Conf(sc2 => sc1): 0.40789473684210525

# %%
a = n_both / n_sc2
b = n_sc1 / n_all
print('Lift(sc1 => sc2):', a/b)
# Out:
# Lift(sc1 => sc2): 1.0541695146958305
