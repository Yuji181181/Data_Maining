# %% [markdown]
# ### DM-10 Quiz

# %% [markdown]
# **Ans. get_recomm_by_user_sim**

# %%
import pandas as pd
from numpy.random import randint

items = ['awabi', 'ikura', 'uni', 'maguro', 'hamachi']

res = {}
for item1 in items:
    score1 = randint(0, 5)
    res[item1] = score1

ser_res = xxx (1) xxx  # resをSeriesに型変換してser_resに代入する / Convert res into Series
print(xxx (2) xxx)  # ser_res をスコアの降順にソート / Sort ser_res in descending order of the scores
# Out:
# ikura      4
# maguro     3
# awabi      2
# uni        2
# hamachi    2
# dtype: int64
